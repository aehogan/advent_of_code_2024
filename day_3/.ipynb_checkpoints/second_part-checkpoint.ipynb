# %%
import re
import numpy as np

# %%
with open('input.txt') as f:
    input = f.readlines()
input
len(input)
# Out:
# 6

# %%
sum = 0
for line in input:
    print(line)
    
    dos = np.array([0] + [match.start() for match in re.finditer(r"do\(\)", line)])
    donts = np.array([match.start() for match in re.finditer(r"don't\(\)", line)])

    #print(dos)
    #print(donts)

    for match in re.finditer(r"mul\([0-9][0-9]?[0-9]?,[0-9][0-9]?[0-9]?\)", line):
        #print(match.group(), match.start())
        data = np.array([int(x) for x in match.group().split('(')[1].split(')')[0].split(',')])
        #print('do idx', np.max(dos[dos <= match.start()]))
        if len(donts[donts < match.start()]) != 0:
            #print('dont idx', np.max(donts[donts < match.start()]))
            if np.max(dos[dos < match.start()]) > np.max(donts[donts < match.start()]):
                print('do', match.group(), data[0] * data[1])
                sum += data[0] * data[1]
            else:
                print('dont')
        else:
            print('do', match.group(), data[0] * data[1])
            sum += data[0] * data[1]
            
            

print(sum)
# 215775 low
# 318076 low
# 77877805 high
# Out:
# do mul(73,623) 45479
# do mul(793,458) 363194
# do mul(709,198) 140382
# do mul(395,622) 245690
# do mul(970,343) 332710
# do mul(75,7) 525
# do mul(61,40) 2440
# do mul(892,307) 273844
# do mul(412,807) 332484
# do mul(706,931) 657286
# do mul(953,62) 59086
# do mul(461,410) 189010
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# do mul(605,52) 31460
# do mul(597,962) 574314
# do mul(903,469) 423507
# do mul(588,272) 159936
# do mul(295,621) 183195
# do mul(900,24) 21600
# do mul(574,932) 534968
# do mul(350,308) 107800
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# do mul(981,750) 735750
# do mul(927,646) 598842
# do mul(67,435) 29145
# do mul(819,795) 651105
# do mul(215,234) 50310
# do mul(992,63) 62496
# do mul(526,962) 506012
# do mul(730,728) 531440
# do mul(687,974) 669138
# do mul(259,420) 108780
# do mul(483,827) 399441
# do mul(368,168) 61824
# do mul(629,217) 136493
# do mul(83,255) 21165
# do mul(500,689) 344500
# do mul(592,556) 329152
# do mul(747,249) 186003
# do mul(762,891) 678942
# do mul(873,69) 60237
# do mul(591,81) 47871
# do mul(151,432) 65232
# do mul(233,269) 62677
# do mul(402,497) 199794
# do mul(520,79) 41080
# do mul(340,948) 322320
# do mul(410,461) 189010
# do mul(511,538) 274918
# do mul(443,727) 322061
# do mul(302,402) 121404
# do mul(599,23) 13777
# do mul(823,16) 13168
# do mul(502,890) 446780
# do mul(25,421) 10525
# do mul(652,45) 29340
# do mul(783,401) 313983
# do mul(828,237) 196236
# do mul(724,536) 388064
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# dont
# do mul(987,108) 106596
# do mul(561,928) 520608
# do mul(242,236) 57112
# do mul(401,270) 108270
# do mul(850,190) 161500
# do mul(511,942) 481362
# do mul(404,904) 365216
# do mul(891,878) 782298
# do mul(381,288) 109728
# do mul(282,737) 207834
# do mul(60,709) 42540
# do mul(890,902) 802780
# do mul(539,945) 509355
# do mul(175,630) 110250
# do mul(103,549) 56547
# do mul(408,760) 310080
# do mul(796,714) 568344
# do mul(557,352) 196064
# do mul(135,816) 110160
# do mul(812,707) 574084
# do mul(305,996) 303780
# do mul(19,420) 7980
# do mul(678,132) 89496
# do mul(775,858) 664950
# do mul(151,737) 111287
