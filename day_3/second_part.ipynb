# %%
import re
import numpy as np

# %%
with open('input.txt') as f:
    input = f.readlines()
input
len(input)
# Out:
# 6

# %%
sum = 0
for line in input:
    print(line)
    
    dos = np.array([0] + [match.start() for match in re.finditer(r"do\(\)", line)])
    donts = np.array([match.start() for match in re.finditer(r"don't\(\)", line)])

    #print(dos)
    #print(donts)

    for match in re.finditer(r"mul\([0-9][0-9]?[0-9]?,[0-9][0-9]?[0-9]?\)", line):
        #print(match.group(), match.start())
        data = np.array([int(x) for x in match.group().split('(')[1].split(')')[0].split(',')])
        #print('do idx', np.max(dos[dos <= match.start()]))
        if len(donts[donts < match.start()]) != 0:
            #print('dont idx', np.max(donts[donts < match.start()]))
            if np.max(dos[dos < match.start()]) > np.max(donts[donts < match.start()]):
                print(match.group(), data[0] * data[1])
                sum += data[0] * data[1]
            else:
                pass
                #print('dont')
        else:
            print(match.group(), data[0] * data[1])
            sum += data[0] * data[1]
            
            

print(sum)
# 215775 low
# 318076 low
# 77877805 high
# 7787780 wrong
# Out:
# (%%from() when()mul(73,623)when()mul(793,458)'~where()how()?how(569,237)/[mul(709,198)mul(395,622)$!what()select()^@/what()+mul(970,343)mul(75,7)^))mul(61,40)select()~why())'>where()%+mul(892,307),!(mul(412,807):*&what()+^why()<^why()mul(706,931)'{who())why()^?mul(953,62)(mul(461,410)when()don't()>^@<%who()'mul(365,15)(<^<# (where()mul(802,710)why()*[(  where()where()mul(684,352)&)&what()^<[>mul(246,913)+select()?how(489,271)when() }why(627,30);don't()+&<@where()when()mul(636,990)]/mul(767,759):mul(328,474)([^,-select()?(mul(825,353)select()where()*where()what()*-@mul(765,991)where(786,744)'--where()mul(990,947) mul(547,706)from()?mul(229,193)where(617,453)+@&where()]@%}/mul(128,550)<%mul(3,636)don't()^(+#>+mul(66,503) select()#when()%from()mul(59,150)how(),when()^:mul(614,438)where()*<[where();(mul(434,344) /how()$ (%?~when()mul(659,534)mul(809,367) where(42,397),);? ++select()mul(858,771)<*mul(106,962)^>@;# @?,*mul(208,462)'',)mul(762,748)+[?}>][^mul(126,384))@]): /(('mul(966,704)w
# ...
